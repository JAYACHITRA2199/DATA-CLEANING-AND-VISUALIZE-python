# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Exploratory Data Analysis
# Data Collection. Data collection is an essential part of exploratory data analysis. ...
#
# Data Cleaning. Data cleaning refers to the process of removing unwanted variables and values from your dataset and getting rid of any irregularities in it. ...

# %% [markdown]
# # Google Play Store App EDA & Data Visualization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Table of contents:
#
# Loading the dataset
# Understanding the dataset
# Handling missing data
# Data preprocessing
# Data visualization

# %% [markdown]
# # Loading The Dataset

# %% [markdown]
# Apps dataset columns descriptions:
#
# This file contains all the details of the apps on Google Play. There are 9 features that describe a given app.
#
# App: Name of the app
# Category: Category of the app. Some examples are: ART_AND_DESIGN, FINANCE, COMICS, BEAUTY etc.
# Rating: The current average rating (out of 5) of the app on Google Play
# Reviews: Number of user reviews given on the app
# Size: Size of the app in MB (megabytes)
# Installs: Number of times the app was downloaded from Google Play
# Type: Whether the app is paid or free
# Price: Price of the app in US$
# Last Updated: Date on which the app was last updated on Google Play

# %% [markdown]
# # 1.IMPORT LIBRARIES FILES

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sn

# %%
google_data=pd.read_csv("https://raw.githubusercontent.com/JAYACHITRA2199/data-files/PYTHON-FILES/googleplaystore1.csv")
google_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 1.Display Top 5 Rows of The Dataset

# %%
google_data.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Understanding The Dataset

# %% [markdown]
# # find the columns and shape

# %%
google_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
google_data.shape
# Out:
# (10841, 13)

# %%
google_data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# # Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Get Overall Statistics About The Dataframe

# %%
google_data. describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# Let's have a look at missing data in columns.

# %%
google_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # To visualize missing data, let me use seaborn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Let's set the theme of plots.
sns.set_theme()
sns.set(rc={"figure.dpi":300, "figure.figsize":(12,9)})

# %% [markdown]
# To see missing data, I'm going to use the heatmap method

# %%
sns.heatmap(google_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
rating_median = google_data["Rating"].median()
print(rating_median)
google_data["Rating"].fillna(rating_median, inplace=True)
# Out:
# 4.3

# %% [markdown]
# Let's remove the other missing data as it is very little.

# %%
df.dropna(inplace=True)

# %% [markdown]
# Let's take a look at missing data again.

# %%
google_data.isnull().sum().sum()
# Out:
# 13

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Handling the review column

# %%
google_data["Reviews"].describe()
# Out:
# count     10841
# unique     6002
# top           0
# freq        596
# Name: Reviews, dtype: object

# %% [markdown]
# # Handling the size column

# %%
print(len(google_data["Size"].unique()))
google_data["Size"].unique()
# Out:
# 462
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
google_data.Size = pd.to_numeric(google_data.Size)

# %%
google_data.Size.head()
# Out:
# 0     19M
# 1     14M
# 2    8.7M
# 3     25M
# 4    2.8M
# Name: Size, dtype: object

# %% [markdown]
# # Handling the installs column

# %%
google_data["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# Let's remove the + symbol in this column

# %%
google_data.Installs = df.Installs.apply(lambda x:x.replace("+",""))
google_data.Installs = df.Installs.apply(lambda x:x.replace(",",""))
google_data.Installs = df.Installs.apply(lambda x:int(x))

# %%
google_data["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# # Handling the price column

# %%
google_data["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %% [markdown]
# # Handling the genres column

# %%
len(google_data["Genres"].unique())
# Out:
# 120

# %%
google_data["Genres"].head(10)
# Out:
# 0                 Art & Design
# 1    Art & Design;Pretend Play
# 2                 Art & Design
# 3                 Art & Design
# 4      Art & Design;Creativity
# 5                 Art & Design
# 6                 Art & Design
# 7                 Art & Design
# 8                 Art & Design
# 9      Art & Design;Creativity
# Name: Genres, dtype: object

# %%
google_data["Genres"].value_counts()
# Out:
# Tools                     842
# Entertainment             623
# Education                 549
# Medical                   463
# Business                  460
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: Genres, Length: 120, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# pie plot for the size column

# %%
google_data["Type"].value_counts().plot(kind="bar", color ="brown")
plt.title("Free & Paid")
# Out:
# Text(0.5, 1.0, 'Free & Paid')

# %% [markdown]
# Free apps are more than Paid apps.

# %% [markdown]
# Box plot for the rating column

# %%
sns.boxplot(x = "Type", y = "Rating", data = google_data)
plt.title("Content rating with their counts")
# Out:
# Text(0.5, 1.0, 'Content rating with their counts')

# %% [markdown]
# Bar plot for the rating column with the number of the categories

# %%
sns.countplot(y = "Rating", data = google_data)
plt.title(" rating with their counts")
# Out:
# Text(0.5, 1.0, ' rating with their counts')

# %% [markdown]
# Histogram with the kde for the rating column

# %%
sns.histplot(google_data["Rating"], kde = True)
plt.title("Histogram with the kde for the rating column ", size=40,)
# Out:
# Text(0.5, 1.0, 'Histogram with the kde for the rating column ')

# %% [markdown]
# scatter plot for the category and price

# %%
sns.scatterplot(data = google_data, y = "Category", x = "Price")
plt.title("Category & Price", size=20)
# Out:
# Text(0.5, 1.0, 'Category & Price')
